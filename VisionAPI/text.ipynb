# %%
from visionAPI import visionAPI
import matplotlib.pyplot as plt
import cv2

img_dir = 'C:/TeamProject_/mingco_ocr/media/Uploaded_files/prescription2.jpg'
prescription1 = visionAPI(img_dir)
prescription1.pills

prescription1.img_out

word_list = [i[2] for i in prescription1.pills]
print(word_list)

plt.figure(figsize=(12, 10))
plt.imshow(cv2.cvtColor(prescription1.img_out, cv2.COLOR_BGR2RGB))
# Out:
# [[0, 8, '씬지로이드정'], [9, 15, '팩사엑스알서방캅셀'], [16, 24, '푸로작확산정'], [25, 33, '페니드정'], [34, 42, '알프람정'], [43, 51, '졸민정'], [52, 57, '삼진디아제팜정'], [58, 63, '환인염산트라조돈캅셀'], [64, 70, '유니작정'], [71, 79, '설피딘정'], [80, 89, '정']]
# ['씬지로이드정', '팩사엑스알서방캅셀', '푸로작확산정', '페니드정', '알프람정', '졸민정', '삼진디아제팜정', '환인염산트라조돈캅셀', '유니작정', '설피딘정', '정']
