# %%
from visionAPI import visionAPI
import matplotlib.pyplot as plt
import cv2
import io 
import base64
import numpy as np

img_dir = 'C:/TeamProject_/mingco_ocr/media/Uploaded_files/image26.jpg'

with io.open(img_dir, 'rb') as image_file:
    content = image_file.read()

n = base64.b64encode(content)
# print(n)
n2 = n.decode('ascii')

prescription1 = visionAPI(n2)
prescription1.pills

print(prescription1.img_out)

# if prescription1.pills:
#     word_list = [i[2] for i in prescription1.pills]
#     print(word_list)

plt.figure(figsize=(12, 10))
plt.imshow(prescription1.img_out)
# Out:
# <PIL.Image.Image image mode=RGB size=563x506 at 0x1B09DB4F160>
